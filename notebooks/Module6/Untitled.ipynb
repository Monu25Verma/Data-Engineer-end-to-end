# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
schema = StructType([
    StructField("customer_id", IntegerType(), True),
    StructField("customer_name", StringType(), True),
    StructField("gender", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("product", StringType(), True),
    StructField("purschase_amount", StringType(), True)
])

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("test").getOrCreate()

data = spark.read.option("header", 'true') \
        .option("InferSchema", 'true') \
        .schema(schema) \
        .csv("module6data.csv")
data.show()
# Out:
# +-----------+--------------+------+---+--------------------+----------------+
# |customer_id| customer_name|gender|age|             product|purschase_amount|
# +-----------+--------------+------+---+--------------------+----------------+
# |          1|  Aarav Sharma|  male| 45|AquaGlow Water Bo...|             499|
# |          2|   Priya Patel|female| 12|SmartFit Fitness ...|           2,999|
# |          4|   Rohan Verma|  male| 89|EcoFresh Air Puri...|           8,499|
# |          6|    Neha Gupta|female| 33|TurboCharge Power...|           1,799|
# |          5|   Karan Singh|  male| 12|FlexiGrip Phone H...|             349|
# |          6|  Ananya Mehta|female| 90|    UltraSoft Pillow|             899|
# |          7|   Vivek Kumar|  male| 45| BrightBeam LED Lamp|           1,299|
# |          8|   Sneha Joshi|female| 32|QuickBrew Coffee ...|           3,999|
# |          9|Rahul Malhotra|  male| 67|SonicWave Bluetoo...|           2,499|
# |         10|    Pooja Nair|female| 44|PureBlend Mixer G...|           4,799|
# |         11| Aditya Kapoor|  male| 22| CoolMist Humidifier|              na|
# |         12|    Kavya Iyer|female| 12|SecureLock Smart ...|           1,099|
# |         13|  Manish Yadav|  male| 31|SwiftCharge USB-C...|             299|
# |         14|   Divya Reddy|female| 53|ComfortPro Office...|           9,999|
# |         15|   Arjun Desai| other| 33|FreshKeep Food Co...|             699|
# |         16|    Meera Shah|female| 22|SkyView Drone Camera|          24,999|
# |         17|Saurabh Mishra|  male| 55|ActiveRun Sports ...|           3,499|
# |         18| Nisha Agarwal|female| 66|CrystalSound Earbuds|           1,999|
# |         19|    Akash Jain|  male| 33|HomeGuard Securit...|           5,499|
# |         20|   Ritu Chawla|female| 22| TravelEase Backpack|           1,499|
# +-----------+--------------+------+---+--------------------+----------------+
# only showing top 20 rows
